# %% [markdown]
# # Hello World!
#
# Here's an example notebook with some documentation on how to access CMIP data.

# %%
# %matplotlib inline

import xarray as xr
import intake

# util.py is in the local directory
# it contains code that is common across project notebooks
# or routines that are too extensive and might otherwise clutter
# the notebook design
import util

# %%
print('hello world!')
# Out:
# hello world!

# %% [markdown]
# ## Demonstrate how to use `intake-esm`
# [Intake-esm](https://intake-esm.readthedocs.io) is a data cataloging utility that facilitates access to CMIP data. It's pretty awesome.
#
# An `intake-esm` collection object establishes a link to a database that contains file locations and associated metadata (i.e. which experiement, model, etc. thet come from).
#
# ### Opening a collection
# First step is to open a collection by pointing to the collection definition file, which is a JSON file that conforms to the [ESM Collection Specification](https://github.com/NCAR/esm-collection-spec).
#
# The collection JSON files are stored locally in this repository for purposes of reproducibility---and because Cheyenne compute nodes don't have Internet access.
#
# The primary source for these files is the [intake-esm-datastore](https://github.com/NCAR/intake-esm-datastore) repository. Any changes made to these files should be pulled from that repo. For instance, the Pangeo cloud collection is available [here](https://raw.githubusercontent.com/NCAR/intake-esm-datastore/master/catalogs/pangeo-cmip6.json).

# %%
if util.is_ncar_host():
    col = intake.open_esm_datastore("../catalogs/glade-cmip6.json")
else:
    col = intake.open_esm_datastore("../catalogs/pangeo-cmip6.json")
col
# Out:
# glade-cmip6-ESM Collection with 687919 entries:
# 	> 12 activity_id(s)
#
# 	> 24 institution_id(s)
#
# 	> 47 source_id(s)
#
# 	> 66 experiment_id(s)
#
# 	> 162 member_id(s)
#
# 	> 35 table_id(s)
#
# 	> 1027 variable_id(s)
#
# 	> 12 grid_label(s)
#
# 	> 59 dcpp_init_year(s)
#
# 	> 246 version(s)
#
# 	> 6667 time_range(s)
#
# 	> 687919 path(s)

# %% [markdown]
# `intake-esm` is build on top of [pandas](https://pandas.pydata.org/pandas-docs/stable). It is possible to view the `pandas.DataFrame` as follows.

# %%
col.df.head()
# Out:
#   activity_id institution_id source_id experiment_id member_id table_id  \
# 0  AerChemMIP            BCC  BCC-ESM1        ssp370  r2i1p1f1      day
# 1  AerChemMIP            BCC  BCC-ESM1        ssp370  r2i1p1f1     Amon
# 2  AerChemMIP            BCC  BCC-ESM1        ssp370  r2i1p1f1     Amon
# 3  AerChemMIP            BCC  BCC-ESM1        ssp370  r2i1p1f1     Amon
# 4  AerChemMIP            BCC  BCC-ESM1        ssp370  r2i1p1f1     Amon
#
#   variable_id grid_label  dcpp_init_year    version         time_range  \
# 0          pr         gn             NaN  v20190702  20150101-20551231
# 1        hfls         gn             NaN  v20190624      201501-205512
# 2        prsn         gn             NaN  v20190624      201501-205512
# 3          va         gn             NaN  v20190624      201501-205512
# 4         tas         gn             NaN  v20190624      201501-205512
#
#                                                 path
# 0  /glade/collections/cmip/CMIP6/AerChemMIP/BCC/B...
# 1  /glade/collections/cmip/CMIP6/AerChemMIP/BCC/B...
# 2  /glade/collections/cmip/CMIP6/AerChemMIP/BCC/B...
# 3  /glade/collections/cmip/CMIP6/AerChemMIP/BCC/B...
# 4  /glade/collections/cmip/CMIP6/AerChemMIP/BCC/B...

# %% [markdown]
# It is possible to interact with the `DataFrame`; for instance, we can see what the "attributes" of the datasets are by printing the columns.

# %%
col.df.columns
# Out:
# Index(['activity_id', 'institution_id', 'source_id', 'experiment_id',
#        'member_id', 'table_id', 'variable_id', 'grid_label', 'dcpp_init_year',
#        'version', 'time_range', 'path'],
#       dtype='object')

# %% [markdown]
# ### Search and discovery
#
# #### Finding unique entries
# Let's query the data to see what models ("source_id"), experiments ("experiment_id") and temporal frequencies ("table_id") are available.

# %%
import pprint 
uni_dict = col.unique(['source_id', 'experiment_id', 'table_id'])

pprint.pprint(uni_dict, compact=True)
# Out:
# {'experiment_id': {'count': 66,
#                    'values': ['ssp370', 'histSST-piNTCF', 'histSST',
#                               'histSST-1950HC', 'hist-1950HC', 'hist-piNTCF',
#                               'piClim-NTCF', 'ssp370SST-lowNTCF',
#                               'ssp370-lowNTCF', 'ssp370SST', 'hist-bgc',
#                               'esm-ssp585', 'amip-future4K', 'amip-m4K',
#                               'a4SST', 'aqua-p4K', 'piSST', 'amip-4xCO2',
#                               'a4SSTice', 'amip-p4K', 'aqua-control',
#                               'aqua-4xCO2', 'abrupt-4xCO2', 'historical',
#                               'piControl', 'amip', '1pctCO2', 'esm-piControl',
#                               'esm-hist', 'ssp245', 'ssp585', 'ssp126',
#                               'hist-GHG', 'hist-aer', 'dcppA-hindcast',
#                               'dcppC-hindcast-noPinatubo',
#                               'dcppC-hindcast-noElChichon', 'dcppA-assim',
#                               'dcppC-hindcast-noAgung', 'hist-1950',
#                               'highresSST-present', 'control-1950',
#                               'land-hist-princeton', 'land-hist-cruNcep',
#                               'land-hist', 'deforest-globe',
#                               'esm-ssp585-ssp126Lu', 'land-cCO2', 'hist-noLu',
#                               'land-crop-noFert', 'ssp370-ssp126Lu',
#                               'ssp126-ssp370Lu', 'land-noLu', 'land-noFire',
#                               'land-hist-altStartYear', 'land-cClim', 'omip1',
#                               'pdSST-piAntSIC', 'pdSST-futAntSIC',
#                               'pdSST-pdSIC', 'pdSST-piArcSIC',
#                               'pdSST-futArcSIC', 'ssp119', 'ssp434', 'ssp460',
#                               'ssp534-over']},
#  'source_id': {'count': 47,
#                'values': ['BCC-ESM1', 'CESM2-WACCM', 'CESM2', 'CNRM-ESM2-1',
#                           'BCC-CSM2-MR', 'UKESM1-0-LL', 'GFDL-ESM4',
#                           'GISS-E2-1-G', 'CanESM5', 'CNRM-CM6-1', 'FGOALS-f3-L',
#                           'FGOALS-g3', 'SAM0-UNICON', 'HadGEM3-GC31-LL',
#                           'HadGEM3-GC31-MM', 'AWI-CM-1-1-MR', 'GFDL-AM4',
#                           'GFDL-CM4', 'GISS-E2-1-H', 'E3SM-1-0', 'CAMS-CSM1-0',
#                           'MCM-UA-1-0', 'EC-Earth3-LR', 'EC-Earth3',
#                           'EC-Earth3-Veg', 'MRI-ESM2-0', 'NESM3', 'MIROC-ES2L',
#                           'MIROC6', 'IPSL-CM6A-LR', 'NorCPM1', 'NorESM2-LM',
#                           'FIO-ESM-2-0', 'CNRM-CM6-1-HR', 'FGOALS-f3-H',
#                           'HadGEM3-GC31-HM', 'HadGEM3-GC31-LM', 'GFDL-CM4C192',
#                           'ECMWF-IFS-LR', 'ECMWF-IFS-HR', 'CMCC-CM2-VHR4',
#                           'CMCC-CM2-HR4', 'NICAM16-7S', 'NICAM16-8S',
#                           'NICAM16-9S', 'IPSL-CM6A-ATM-HR', 'MPI-ESM1-2-HR']},
#  'table_id': {'count': 35,
#               'values': ['day', 'Amon', 'AERmonZ', 'CFmon', 'EdayZ', 'Eday',
#                          'CFday', 'EmonZ', 'AERday', 'Emon', 'fx', 'Lmon',
#                          'AERmon', 'Ofx', 'Omon', 'SImon', 'Oyr', 'AERhr',
#                          'Eyr', 'LImon', 'SIday', '6hrPlev', 'CFsubhr',
#                          '6hrLev', 'Oday', 'ImonGre', 'ImonAnt', 'Efx',
#                          'IfxGre', '3hr', '6hrPlevPt', 'E1hr', 'E3hr', 'Oclim',
#                          'CF3hr']}}

# %% [markdown]
# #### Searching for specific datasets
#
# Let's find all the dissolved oxygen data at annual frequency from the ocean for the `historical` and `ssp585` experiments.

# %%
cat = col.search(experiment_id=['dcppC-hindcast-noPinatubo']) #table_id='Amon', variable_id='ts', grid_label='gn')
cat.df
# Out:
#        activity_id institution_id source_id              experiment_id  \
# 563285        DCPP          CCCma   CanESM5  dcppC-hindcast-noPinatubo
# 563286        DCPP          CCCma   CanESM5  dcppC-hindcast-noPinatubo
# 563287        DCPP          CCCma   CanESM5  dcppC-hindcast-noPinatubo
# 563288        DCPP          CCCma   CanESM5  dcppC-hindcast-noPinatubo
# 563289        DCPP          CCCma   CanESM5  dcppC-hindcast-noPinatubo
# 563290        DCPP          CCCma   CanESM5  dcppC-hindcast-noPinatubo
# 563291        DCPP          CCCma   CanESM5  dcppC-hindcast-noPinatubo
# 563292        DCPP          CCCma   CanESM5  dcppC-hindcast-noPinatubo
# 563293        DCPP          CCCma   CanESM5  dcppC-hindcast-noPinatubo
#
#         member_id table_id variable_id grid_label  dcpp_init_year    version  \
# 563285   r8i1p2f1     Amon         tas         gn          1990.0  v20190429
# 563286   r5i1p2f1     Amon         tas         gn          1990.0  v20190429
# 563287   r1i1p2f1     Amon         tas         gn          1990.0  v20190429
# 563288   r7i1p2f1     Amon         tas         gn          1990.0  v20190429
# 563289   r9i1p2f1     Amon         tas         gn          1990.0  v20190429
# 563290  r10i1p2f1     Amon         tas         gn          1990.0  v20190429
# 563291   r2i1p2f1     Amon         tas         gn          1990.0  v20190429
# 563292   r4i1p2f1     Amon         tas         gn          1990.0  v20190429
# 563293   r3i1p2f1     Amon         tas         gn          1990.0  v20190429
#
#            time_range                                               path
# 563285  199101-200012  /glade/collections/cmip/CMIP6/DCPP/CCCma/CanES...
# 563286  199101-200012  /glade/collections/cmip/CMIP6/DCPP/CCCma/CanES...
# 563287  199101-200012  /glade/collections/cmip/CMIP6/DCPP/CCCma/CanES...
# 563288  199101-200012  /glade/collections/cmip/CMIP6/DCPP/CCCma/CanES...
# 563289  199101-200012  /glade/collections/cmip/CMIP6/DCPP/CCCma/CanES...
# 563290  199101-200012  /glade/collections/cmip/CMIP6/DCPP/CCCma/CanES...
# 563291  199101-200012  /glade/collections/cmip/CMIP6/DCPP/CCCma/CanES...
# 563292  199101-200012  /glade/collections/cmip/CMIP6/DCPP/CCCma/CanES...
# 563293  199101-200012  /glade/collections/cmip/CMIP6/DCPP/CCCma/CanES...

# %%
cat = col.search(source_id=['CESM2'],experiment_id=['historical'], table_id='Amon', variable_id='ts')
#grid_label='gn'
cat.df
# Out:
#        activity_id institution_id source_id experiment_id  member_id table_id  \
# 88140         CMIP           NCAR     CESM2    historical   r2i1p1f1     Amon
# 90571         CMIP           NCAR     CESM2    historical   r5i1p1f1     Amon
# 92806         CMIP           NCAR     CESM2    historical   r1i1p1f1     Amon
# 95041         CMIP           NCAR     CESM2    historical   r4i1p1f1     Amon
# 97276         CMIP           NCAR     CESM2    historical   r3i1p1f1     Amon
# 101883        CMIP           NCAR     CESM2    historical   r9i1p1f1     Amon
# 101884        CMIP           NCAR     CESM2    historical   r9i1p1f1     Amon
# 101885        CMIP           NCAR     CESM2    historical   r9i1p1f1     Amon
# 101886        CMIP           NCAR     CESM2    historical   r9i1p1f1     Amon
# 106849        CMIP           NCAR     CESM2    historical   r8i1p1f1     Amon
# 106850        CMIP           NCAR     CESM2    historical   r8i1p1f1     Amon
# 106851        CMIP           NCAR     CESM2    historical   r8i1p1f1     Amon
# 106852        CMIP           NCAR     CESM2    historical   r8i1p1f1     Amon
# 112094        CMIP           NCAR     CESM2    historical  r10i1p1f1     Amon
# 112095        CMIP           NCAR     CESM2    historical  r10i1p1f1     Amon
# 112096        CMIP           NCAR     CESM2    historical  r10i1p1f1     Amon
# 112097        CMIP           NCAR     CESM2    historical  r10i1p1f1     Amon
# 117393        CMIP           NCAR     CESM2    historical   r7i1p1f1     Amon
# 117394        CMIP           NCAR     CESM2    historical   r7i1p1f1     Amon
# 117395        CMIP           NCAR     CESM2    historical   r7i1p1f1     Amon
# 117396        CMIP           NCAR     CESM2    historical   r7i1p1f1     Amon
# 123068        CMIP           NCAR     CESM2    historical  r11i1p1f1     Amon
# 123069        CMIP           NCAR     CESM2    historical  r11i1p1f1     Amon
# 123070        CMIP           NCAR     CESM2    historical  r11i1p1f1     Amon
# 123071        CMIP           NCAR     CESM2    historical  r11i1p1f1     Amon
# 125811        CMIP           NCAR     CESM2    historical   r6i1p1f1     Amon
#
#        variable_id grid_label  dcpp_init_year    version     time_range  \
# 88140           ts         gn             NaN  v20190308  185001-201412
# 90571           ts         gn             NaN  v20190308  185001-201412
# 92806           ts         gn             NaN  v20190308  185001-201412
# 95041           ts         gn             NaN  v20190308  185001-201412
# 97276           ts         gn             NaN  v20190308  185001-201412
# 101883          ts         gn             NaN  v20190311  200001-201412
# 101884          ts         gn             NaN  v20190311  190001-194912
# 101885          ts         gn             NaN  v20190311  195001-199912
# 101886          ts         gn             NaN  v20190311  185001-189912
# 106849          ts         gn             NaN  v20190311  190001-194912
# 106850          ts         gn             NaN  v20190311  185001-189912
# 106851          ts         gn             NaN  v20190311  200001-201412
# 106852          ts         gn             NaN  v20190311  195001-199912
# 112094          ts         gn             NaN  v20190313  195001-199912
# 112095          ts         gn             NaN  v20190313  200001-201412
# 112096          ts         gn             NaN  v20190313  185001-189912
# 112097          ts         gn             NaN  v20190313  190001-194912
# 117393          ts         gn             NaN  v20190311  195001-199912
# 117394          ts         gn             NaN  v20190311  200001-201412
# 117395          ts         gn             NaN  v20190311  190001-194912
# 117396          ts         gn             NaN  v20190311  185001-189912
# 123068          ts         gn             NaN  v20190514  200001-201412
# 123069          ts         gn             NaN  v20190514  195001-199912
# 123070          ts         gn             NaN  v20190514  190001-194912
# 123071          ts         gn             NaN  v20190514  185001-189912
# 125811          ts         gn             NaN  v20190308  185001-201412
#
#                                                      path
# 88140   /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 90571   /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 92806   /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 95041   /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 97276   /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 101883  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 101884  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 101885  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 101886  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 106849  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 106850  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 106851  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 106852  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 112094  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 112095  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 112096  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 112097  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 117393  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 117394  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 117395  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 117396  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 123068  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 123069  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 123070  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 123071  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 125811  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...

# %% [markdown]
# It might be desirable to get more specific. For instance, we may want to select only the models that have *both* `historical` and `ssp585` data. We coud do this as follows.

# %%
models = set(uni_dict['source_id']['values']) # all the models

for experiment_id in ['historical']:
    query = dict(experiment_id=experiment_id, table_id='Amon', 
                 variable_id='ts')  
    #grid_label='gn'
    cat = col.search(**query)
    models = models.intersection({model for model in cat.df.source_id.unique().tolist()})

## ensure the CESM2 models are not included (oxygen was erroneously submitted to the archive)
#models = models - {'CESM2-WACCM', 'CESM2'}

models = list(models)
models
# Out:
# ['SAM0-UNICON',
#  'GFDL-ESM4',
#  'CAMS-CSM1-0',
#  'GFDL-CM4',
#  'BCC-CSM2-MR',
#  'NESM3',
#  'BCC-ESM1',
#  'MCM-UA-1-0',
#  'CanESM5',
#  'UKESM1-0-LL',
#  'CESM2',
#  'IPSL-CM6A-LR',
#  'EC-Earth3-Veg',
#  'GISS-E2-1-G',
#  'CNRM-CM6-1',
#  'E3SM-1-0',
#  'HadGEM3-GC31-LL',
#  'GISS-E2-1-H',
#  'EC-Earth3',
#  'NorESM2-LM',
#  'MIROC-ES2L',
#  'MIROC6',
#  'FGOALS-g3',
#  'CNRM-ESM2-1',
#  'CESM2-WACCM',
#  'MRI-ESM2-0']

# %%
cat = col.search(source_id=['CESM2'], experiment_id=['historical'], table_id='Amon', 
                 variable_id='ts')#, source_id=models
cat.df
# Out:
#        activity_id institution_id source_id experiment_id  member_id table_id  \
# 88140         CMIP           NCAR     CESM2    historical   r2i1p1f1     Amon
# 90571         CMIP           NCAR     CESM2    historical   r5i1p1f1     Amon
# 92806         CMIP           NCAR     CESM2    historical   r1i1p1f1     Amon
# 95041         CMIP           NCAR     CESM2    historical   r4i1p1f1     Amon
# 97276         CMIP           NCAR     CESM2    historical   r3i1p1f1     Amon
# 101883        CMIP           NCAR     CESM2    historical   r9i1p1f1     Amon
# 101884        CMIP           NCAR     CESM2    historical   r9i1p1f1     Amon
# 101885        CMIP           NCAR     CESM2    historical   r9i1p1f1     Amon
# 101886        CMIP           NCAR     CESM2    historical   r9i1p1f1     Amon
# 106849        CMIP           NCAR     CESM2    historical   r8i1p1f1     Amon
# 106850        CMIP           NCAR     CESM2    historical   r8i1p1f1     Amon
# 106851        CMIP           NCAR     CESM2    historical   r8i1p1f1     Amon
# 106852        CMIP           NCAR     CESM2    historical   r8i1p1f1     Amon
# 112094        CMIP           NCAR     CESM2    historical  r10i1p1f1     Amon
# 112095        CMIP           NCAR     CESM2    historical  r10i1p1f1     Amon
# 112096        CMIP           NCAR     CESM2    historical  r10i1p1f1     Amon
# 112097        CMIP           NCAR     CESM2    historical  r10i1p1f1     Amon
# 117393        CMIP           NCAR     CESM2    historical   r7i1p1f1     Amon
# 117394        CMIP           NCAR     CESM2    historical   r7i1p1f1     Amon
# 117395        CMIP           NCAR     CESM2    historical   r7i1p1f1     Amon
# 117396        CMIP           NCAR     CESM2    historical   r7i1p1f1     Amon
# 123068        CMIP           NCAR     CESM2    historical  r11i1p1f1     Amon
# 123069        CMIP           NCAR     CESM2    historical  r11i1p1f1     Amon
# 123070        CMIP           NCAR     CESM2    historical  r11i1p1f1     Amon
# 123071        CMIP           NCAR     CESM2    historical  r11i1p1f1     Amon
# 125811        CMIP           NCAR     CESM2    historical   r6i1p1f1     Amon
#
#        variable_id grid_label  dcpp_init_year    version     time_range  \
# 88140           ts         gn             NaN  v20190308  185001-201412
# 90571           ts         gn             NaN  v20190308  185001-201412
# 92806           ts         gn             NaN  v20190308  185001-201412
# 95041           ts         gn             NaN  v20190308  185001-201412
# 97276           ts         gn             NaN  v20190308  185001-201412
# 101883          ts         gn             NaN  v20190311  200001-201412
# 101884          ts         gn             NaN  v20190311  190001-194912
# 101885          ts         gn             NaN  v20190311  195001-199912
# 101886          ts         gn             NaN  v20190311  185001-189912
# 106849          ts         gn             NaN  v20190311  190001-194912
# 106850          ts         gn             NaN  v20190311  185001-189912
# 106851          ts         gn             NaN  v20190311  200001-201412
# 106852          ts         gn             NaN  v20190311  195001-199912
# 112094          ts         gn             NaN  v20190313  195001-199912
# 112095          ts         gn             NaN  v20190313  200001-201412
# 112096          ts         gn             NaN  v20190313  185001-189912
# 112097          ts         gn             NaN  v20190313  190001-194912
# 117393          ts         gn             NaN  v20190311  195001-199912
# 117394          ts         gn             NaN  v20190311  200001-201412
# 117395          ts         gn             NaN  v20190311  190001-194912
# 117396          ts         gn             NaN  v20190311  185001-189912
# 123068          ts         gn             NaN  v20190514  200001-201412
# 123069          ts         gn             NaN  v20190514  195001-199912
# 123070          ts         gn             NaN  v20190514  190001-194912
# 123071          ts         gn             NaN  v20190514  185001-189912
# 125811          ts         gn             NaN  v20190308  185001-201412
#
#                                                      path
# 88140   /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 90571   /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 92806   /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 95041   /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 97276   /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 101883  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 101884  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 101885  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 101886  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 106849  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 106850  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 106851  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 106852  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 112094  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 112095  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 112096  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 112097  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 117393  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 117394  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 117395  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 117396  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 123068  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 123069  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 123070  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 123071  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 125811  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...

# %% [markdown]
# ### Loading data
#
# `intake-esm` enables loading data directly into an [xarray.Dataset](http://xarray.pydata.org/en/stable/api.html#dataset).
#
# Note that data on the cloud are in
# [zarr](https://zarr.readthedocs.io/en/stable/) format and data on
# [glade](https://www2.cisl.ucar.edu/resources/storage-and-file-systems/glade-file-spaces) are stored as
# [netCDF](https://www.unidata.ucar.edu/software/netcdf/) files. This is opaque to the user.
#
# `intake-esm` has rules for aggegating datasets; these rules are defined in the collection-specification file.

# %%
dset_dict = cat.to_dataset_dict(zarr_kwargs={'consolidated': True, 'decode_times': False}, 
                                cdf_kwargs={'chunks': {}, 'decode_times': False})
# Out:
# xarray will load netCDF datasets with dask using a single chunk for all arrays.
# For effective chunking, please provide chunks in cdf_kwargs.
# For example: cdf_kwargs={'chunks': {'time': 36}}
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
#
# --> There will be 1 group(s)
# /ncar/usr/jupyterhub/envs/cmip6-201910/lib/python3.7/site-packages/xarray/conventions.py:494: SerializationWarning: variable 'ts' has multiple fill values {1e+20, 1e+20}, decoding all values to NaN.
#   use_cftime=use_cftime,
# /ncar/usr/jupyterhub/envs/cmip6-201910/lib/python3.7/site-packages/xarray/conventions.py:494: SerializationWarning: variable 'ts' has multiple fill values {1e+20, 1e+20}, decoding all values to NaN.
#   use_cftime=use_cftime,
# /ncar/usr/jupyterhub/envs/cmip6-201910/lib/python3.7/site-packages/xarray/conventions.py:494: SerializationWarning: variable 'ts' has multiple fill values {1e+20, 1e+20}, decoding all values to NaN.
#   use_cftime=use_cftime,
# /ncar/usr/jupyterhub/envs/cmip6-201910/lib/python3.7/site-packages/xarray/conventions.py:494: SerializationWarning: variable 'ts' has multiple fill values {1e+20, 1e+20}, decoding all values to NaN.
#   use_cftime=use_cftime,
# /ncar/usr/jupyterhub/envs/cmip6-201910/lib/python3.7/site-packages/xarray/conventions.py:494: SerializationWarning: variable 'ts' has multiple fill values {1e+20, 1e+20}, decoding all values to NaN.
#   use_cftime=use_cftime,
# /ncar/usr/jupyterhub/envs/cmip6-201910/lib/python3.7/site-packages/xarray/conventions.py:494: SerializationWarning: variable 'ts' has multiple fill values {1e+20, 1e+20}, decoding all values to NaN.
#   use_cftime=use_cftime,
# /ncar/usr/jupyterhub/envs/cmip6-201910/lib/python3.7/site-packages/xarray/conventions.py:494: SerializationWarning: variable 'ts' has multiple fill values {1e+20, 1e+20}, decoding all values to NaN.
#   use_cftime=use_cftime,
# /ncar/usr/jupyterhub/envs/cmip6-201910/lib/python3.7/site-packages/xarray/conventions.py:494: SerializationWarning: variable 'ts' has multiple fill values {1e+20, 1e+20}, decoding all values to NaN.
#   use_cftime=use_cftime,
# /ncar/usr/jupyterhub/envs/cmip6-201910/lib/python3.7/site-packages/xarray/conventions.py:494: SerializationWarning: variable 'ts' has multiple fill values {1e+20, 1e+20}, decoding all values to NaN.
#   use_cftime=use_cftime,
# /ncar/usr/jupyterhub/envs/cmip6-201910/lib/python3.7/site-packages/xarray/conventions.py:494: SerializationWarning: variable 'ts' has multiple fill values {1e+20, 1e+20}, decoding all values to NaN.
#   use_cftime=use_cftime,
# /ncar/usr/jupyterhub/envs/cmip6-201910/lib/python3.7/site-packages/xarray/conventions.py:494: SerializationWarning: variable 'ts' has multiple fill values {1e+20, 1e+20}, decoding all values to NaN.
#   use_cftime=use_cftime,

# %% [markdown]
# `dset_dict` is a dictionary of `xarray.Dataset`'s; its keys are constructed to refer to compatible groups.

# %%
dset_dict.keys()
# Out:
# dict_keys(['CMIP.NCAR.CESM2.historical.Amon.gn'])

# %% [markdown]
# We can access a particular dataset as follows.

# %%
dset_dict['CMIP.NCAR.CESM2.historical.Amon.gn']
# Out:
# <xarray.Dataset>
# Dimensions:    (lat: 192, lon: 288, member_id: 11, nbnd: 2, time: 1980)
# Coordinates:
#   * time       (time) float64 6.749e+05 6.749e+05 ... 7.351e+05 7.351e+05
#   * lon        (lon) float64 0.0 1.25 2.5 3.75 5.0 ... 355.0 356.2 357.5 358.8
#   * lat        (lat) float64 -90.0 -89.06 -88.12 -87.17 ... 88.12 89.06 90.0
#   * member_id  (member_id) <U9 'r10i1p1f1' 'r11i1p1f1' ... 'r8i1p1f1' 'r9i1p1f1'
# Dimensions without coordinates: nbnd
# Data variables:
#     lon_bnds   (lon, nbnd) float64 -0.625 0.625 0.625 ... 358.1 358.1 359.4
#     lat_bnds   (lat, nbnd) float64 -90.0 -89.53 -89.53 ... 89.53 89.53 90.0
#     time_bnds  (time, nbnd) float64 dask.array<chunksize=(600, 2), meta=np.ndarray>
#     ts         (member_id, time, lat, lon) float32 dask.array<chunksize=(1, 600, 192, 288), meta=np.ndarray>
# Attributes:
#     parent_variant_label:   r1i1p1f1
#     forcing_index:          1
#     tracking_id:            hdl:21.14100/20016537-e6d1-403a-be0f-7facdee33089...
#     parent_activity_id:     CMIP
#     institution:            National Center for Atmospheric Research, Climate...
#     product:                model-output
#     experiment:             all-forcing simulation of the recent past
#     frequency:              mon
#     variant_info:           CMIP6 20th century experiments (1850-2014) with C...
#     branch_time_in_parent:  295650.0
#     activity_id:            CMIP
#     institution_id:         NCAR
#     sub_experiment_id:      none
#     parent_source_id:       CESM2
#     grid_label:             gn
#     source:                 CESM2 (2017): atmosphere: CAM6 (0.9x1.25 finite v...
#     initialization_index:   1
#     experiment_id:          historical
#     mip_era:                CMIP6
#     physics_index:          1
#     Conventions:            CF-1.7 CMIP-6.2
#     parent_time_units:      days since 0001-01-01 00:00:00
#     branch_method:          standard
#     data_specs_version:     01.00.29
#     table_id:               Amon
#     variant_label:          r9i1p1f1
#     realm:                  atmos
#     variable_id:            ts
#     nominal_resolution:     100 km
#     external_variables:     areacella
#     parent_mip_era:         CMIP6
#     contact:                cesm_cmip6@ucar.edu
#     source_type:            AOGCM BGC
#     grid:                   native 0.9x1.25 finite volume grid (192x288 latxlon)
#     cesm_casename:          b.e21.BHIST.f09_g17.CMIP6-historical.009
#     license:                CMIP6 model data produced by <The National Center...
#     realization_index:      9
#     sub_experiment:         none
#     further_info_url:       https://furtherinfo.es-doc.org/CMIP6.NCAR.CESM2.h...
#     branch_time_in_child:   674885.0
#     parent_experiment_id:   piControl
#     source_id:              CESM2
#     model_doi_url:          https://doi.org/10.5065/D67H1H0V
#     case_id:                23

# %%
# %matplotlib inline
import intake
import xarray as xr
import numpy as np

# %%
def _compute_slope(y):
    """
    Private function to compute slopes at each grid cell using
    polyfit. 
    """
    x = np.arange(len(y))
    return np.polyfit(x, y, 1)[0] # return only the slope

def compute_slope(da):
    """
    Computes linear slope (m) at each grid cell.
    
    Args:
      da: xarray DataArray to compute slopes for
      
    Returns:
      xarray DataArray with slopes computed at each grid cell.
    """
    # apply_ufunc can apply a raw numpy function to a grid.
    # 
    # vectorize is only needed for functions that aren't already
    # vectorized. You don't need it for polyfit in theory, but it's
    # good to use when using things like np.cov.
    #
    # dask='parallelized' parallelizes this across dask chunks. It requires
    # an output_dtypes of the numpy array datatype coming out.
    #
    # input_core_dims should pass the dimension that is being *reduced* by this operation,
    # if one is being reduced.
    slopes = xr.apply_ufunc(_compute_slope,
                            da,
                            vectorize=True,
                            dask='parallelized', 
                            input_core_dims=[['time']],
                            output_dtypes=[float],
                            )
    return slopes

# %%
col = intake.open_esm_datastore("/glade/collections/cmip/catalog/intake-esm-datastore/catalogs/glade-cmip6.json")

# %%
# Just select CESM2 here for a single ensemble member.
cat = col.search(member_id='r1i1p1f1',
                 experiment_id='historical',
                 activity_id='CMIP',
                 table_id='Omon',
                 variable_id='spco2',
                 grid_label='gn',
                 source_id='CESM2')

# %%
# Chunk over the full time dimension since we're computing slope over the time dimension.
dsets = cat.to_dataset_dict(cdf_kwargs={"chunks": {"time": -1}})

# %%
ds = dsets['CMIP.NCAR.CESM2.historical.Omon.gn'].squeeze()

# %%
single_member = ds['spco2'].load() # Load the single member INTO MEMORY.

# %%
# %%time
slopes = compute_slope(single_member)

# %%
slopes.plot()

# %%
#https://nbviewer.jupyter.org/gist/bradyrx/41e4fa86a92908deecd422503b62a29b

# %% [markdown]
# ### More advanced queries
#
# As motivation for diving into more advanced manipulations with `intake-esm`, let's consider the task of getting access to grid information in the `Ofx` table_id.

# %%
cat_fx = col.search(source_id=['CESM2'], member_id='r1i1p1f1', experiment_id=['historical'], table_id='fx')
cat_fx.df
# Out:
#       activity_id institution_id source_id experiment_id member_id table_id  \
# 92645        CMIP           NCAR     CESM2    historical  r1i1p1f1       fx
# 92646        CMIP           NCAR     CESM2    historical  r1i1p1f1       fx
# 92647        CMIP           NCAR     CESM2    historical  r1i1p1f1       fx
# 92648        CMIP           NCAR     CESM2    historical  r1i1p1f1       fx
#
#       variable_id grid_label  dcpp_init_year    version time_range  \
# 92645      sftgif         gn             NaN  v20190308        NaN
# 92646       sftlf         gn             NaN  v20190308        NaN
# 92647        orog         gn             NaN  v20190308        NaN
# 92648   areacella         gn             NaN  v20190308        NaN
#
#                                                     path
# 92645  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 92646  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 92647  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 92648  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...

# %% [markdown]
# This, however, comes with lots of redundant information.
#
# Additionally, it may be necessary to do more targeted manipulations of the search. For instance, we've found a handful of corrupted files on `glade` and might need to work around loading these.
#
# As an illustration of this, in the code below, we specify a list of to queries (in this case one) to eliminate.

# %%
import numpy as np

# specify a list of queries to eliminate
corrupt_data = [dict(variable_id='areacello', source_id='IPSL-CM6A-LR',
                     experiment_id='historical', member_id='r2i1p1f1')
               ]


# copy the dataframe 
df = cat_fx.df.copy()

# eliminate data
for elim in corrupt_data:
    condition = np.ones(len(df), dtype=bool)
    for key, val in elim.items():
        condition = condition & (df[key] == val)
    df = df.loc[~condition]
df
# Out:
#         activity_id institution_id     source_id experiment_id member_id  \
# 294145         CMIP          CCCma       CanESM5    historical  r2i1p1f1
# 294146         CMIP          CCCma       CanESM5    historical  r2i1p1f1
# 294147         CMIP          CCCma       CanESM5    historical  r2i1p1f1
# 294684         CMIP          CCCma       CanESM5    historical  r5i1p1f1
# 294685         CMIP          CCCma       CanESM5    historical  r5i1p1f1
# ...             ...            ...           ...           ...       ...
# 636507  ScenarioMIP          CCCma       CanESM5        ssp585  r6i1p1f1
# 686900  ScenarioMIP          MIROC    MIROC-ES2L        ssp585  r1i1p1f2
# 687632  ScenarioMIP           IPSL  IPSL-CM6A-LR        ssp585  r1i1p1f1
# 687633  ScenarioMIP           IPSL  IPSL-CM6A-LR        ssp585  r1i1p1f1
# 687634  ScenarioMIP           IPSL  IPSL-CM6A-LR        ssp585  r1i1p1f1
#
#        table_id variable_id grid_label  dcpp_init_year    version time_range  \
# 294145      Ofx   areacello         gn             NaN  v20190429        NaN
# 294146      Ofx    thkcello         gn             NaN  v20190429        NaN
# 294147      Ofx      deptho         gn             NaN  v20190429        NaN
# 294684      Ofx   areacello         gn             NaN  v20190429        NaN
# 294685      Ofx    thkcello         gn             NaN  v20190429        NaN
# ...         ...         ...        ...             ...        ...        ...
# 636507      Ofx      deptho         gn             NaN  v20190429        NaN
# 686900      Ofx       sftof         gn             NaN  v20190823        NaN
# 687632      Ofx   areacello         gn             NaN  v20190119        NaN
# 687633      Ofx      hfgeou         gn             NaN  v20190119        NaN
# 687634      Ofx       basin         gn             NaN  v20190119        NaN
#
#                                                      path
# 294145  /glade/collections/cmip/CMIP6/CMIP/CCCma/CanES...
# 294146  /glade/collections/cmip/CMIP6/CMIP/CCCma/CanES...
# 294147  /glade/collections/cmip/CMIP6/CMIP/CCCma/CanES...
# 294684  /glade/collections/cmip/CMIP6/CMIP/CCCma/CanES...
# 294685  /glade/collections/cmip/CMIP6/CMIP/CCCma/CanES...
# ...                                                   ...
# 636507  /glade/collections/cmip/CMIP6/ScenarioMIP/CCCm...
# 686900  /glade/collections/cmip/CMIP6/ScenarioMIP/MIRO...
# 687632  /glade/collections/cmip/CMIP6/ScenarioMIP/IPSL...
# 687633  /glade/collections/cmip/CMIP6/ScenarioMIP/IPSL...
# 687634  /glade/collections/cmip/CMIP6/ScenarioMIP/IPSL...
#
# [312 rows x 12 columns]

# %% [markdown]
# We then drop duplicates.

# %%
df.drop_duplicates(subset=['source_id', 'variable_id'], inplace=True)

# %% [markdown]
# Now, since we've only retained one ensemble member, we need to eliminate that column. If we omit this step, `intake-esm` will throw an error, complaining that different variables are present for each ensemble member. Setting the `member_id` column to NaN precludes attempts to join along the ensemble dimension.
#
# After this final manipulation, we copy the `DataFrame` back to the collection object and proceed with loading the data.

# %%
df['member_id'] = np.nan
cat_fx.df = df

# %%
fx_dsets = cat_fx.to_dataset_dict(zarr_kwargs={'consolidated': True}, cdf_kwargs={'chunks': {}})
# Out:
# xarray will load netCDF datasets with dask using a single chunk for all arrays.
# For effective chunking, please provide chunks in cdf_kwargs.
# For example: cdf_kwargs={'chunks': {'time': 36}}
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
#
# --> There will be 3 group(s)

# %%
fx_dsets.keys()
# Out:
# dict_keys(['CMIP.CCCma.CanESM5.historical.Ofx.gn', 'CMIP.IPSL.IPSL-CM6A-LR.historical.Ofx.gn', 'CMIP.MIROC.MIROC-ES2L.historical.Ofx.gn'])

# %%
for key, ds in fx_dsets.items():
    print(ds.data_vars)
# Out:
# Data variables:
#     latitude            (j, i) float64 dask.array<chunksize=(291, 360), meta=np.ndarray>
#     longitude           (j, i) float64 dask.array<chunksize=(291, 360), meta=np.ndarray>
#     vertices_latitude   (j, i, vertices) float64 dask.array<chunksize=(291, 360, 4), meta=np.ndarray>
#     vertices_longitude  (j, i, vertices) float64 dask.array<chunksize=(291, 360, 4), meta=np.ndarray>
#     areacello           (j, i) float32 dask.array<chunksize=(291, 360), meta=np.ndarray>
#     lev_bnds            (lev, bnds) float64 dask.array<chunksize=(45, 2), meta=np.ndarray>
#     thkcello            (lev, j, i) float32 dask.array<chunksize=(45, 291, 360), meta=np.ndarray>
#     deptho              (j, i) float32 dask.array<chunksize=(291, 360), meta=np.ndarray>
#     type                |S3 ...
#     sftof               (j, i) float32 dask.array<chunksize=(291, 360), meta=np.ndarray>
# Data variables:
#     nav_lat         (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#     nav_lon         (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#     bounds_nav_lon  (y, x, nvertex) float32 dask.array<chunksize=(332, 362, 4), meta=np.ndarray>
#     bounds_nav_lat  (y, x, nvertex) float32 dask.array<chunksize=(332, 362, 4), meta=np.ndarray>
#     area            (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#     hfgeou          (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#     areacello       (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#     basin           (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
# Data variables:
#     y_bnds              (y, bnds) float64 dask.array<chunksize=(256, 2), meta=np.ndarray>
#     x_bnds              (x, bnds) float64 dask.array<chunksize=(360, 2), meta=np.ndarray>
#     latitude            (y, x) float32 dask.array<chunksize=(256, 360), meta=np.ndarray>
#     longitude           (y, x) float32 dask.array<chunksize=(256, 360), meta=np.ndarray>
#     vertices_latitude   (y, x, vertices) float32 dask.array<chunksize=(256, 360, 4), meta=np.ndarray>
#     vertices_longitude  (y, x, vertices) float32 dask.array<chunksize=(256, 360, 4), meta=np.ndarray>
#     areacello           (y, x) float32 dask.array<chunksize=(256, 360), meta=np.ndarray>
#     type                |S3 ...
#     sftof               (y, x) float32 dask.array<chunksize=(256, 360), meta=np.ndarray>
#     deptho              (y, x) float32 dask.array<chunksize=(256, 360), meta=np.ndarray>

# %% [markdown]
# ## Demonstrate how spin-up a dask cluster
#
# If you expect to require Big Data capabilities, here's how you spin up a [dask](https://dask.org) cluster using [dask-jobqueue](https://dask-jobqueue.readthedocs.io/en/latest/).
#
# The syntax is different if on an NCAR machine versus the cloud.

# %%
if util.is_ncar_host():
    from ncar_jobqueue import NCARCluster
    cluster = NCARCluster(project='UCGD0006')
    cluster.adapt(minimum_jobs=1, maximum_jobs=10)
else:
    from dask_kubernetes import KubeCluster
    cluster = KubeCluster()
    cluster.adapt(minimum=1, maximum=10)
cluster
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-27-adfe82390181> in <module>
#       1 if util.is_ncar_host():
# ----> 2     from ncar_jobqueue import NCARCluster
#       3     cluster = NCARCluster(project='UCGD0006')
#       4     cluster.adapt(minimum_jobs=1, maximum_jobs=10)
#       5 else:
#
# /ncar/usr/jupyterhub/envs/cmip6-201910/lib/python3.7/site-packages/ncar_jobqueue/__init__.py in <module>
#       3 from pkg_resources import DistributionNotFound, get_distribution
#       4
# ----> 5 from . import config
#       6 from .cluster import NCARCluster
#       7
#
# /ncar/usr/jupyterhub/envs/cmip6-201910/lib/python3.7/site-packages/ncar_jobqueue/config.py in <module>
#     100 destination = os.path.join(os.path.expanduser('~'), '.dask')
#     101
# --> 102 with open(config_path, 'w') as outfile:
#     103     data = _generate_config(config_data_file_path, template_file_path)
#     104     data = yaml.safe_load(data)
#
# PermissionError: [Errno 13] Permission denied: '/ncar/usr/jupyterhub/envs/cmip6-201910/lib/python3.7/site-packages/ncar_jobqueue/jobqueue.yaml'

# %%
from dask.distributed import Client
client = Client(cluster) # Connect this local process to remote workers
client
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-2dacf0dd0f19> in <module>
#       1 from dask.distributed import Client
# ----> 2 client = Client(cluster) # Connect this local process to remote workers
#       3 client
#
# NameError: name 'cluster' is not defined
